# %%
import pandas as pd

# %%
#file = 'Interactive_Map_Data.csv'
#this is from the NYC Open Data

# %%
# previous encoding 
#df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
file = 'nyc_movies.csv'
df = pd.read_csv(file, encoding='UTF-8')

# %%
df.head()
# Out:
#                       Film  Year               URL Encoded name  \
# 0  *batteries not included  1987  %2Abatteries%20not%20included
# 1             12 Angry Men  1957               12%20Angry%20Men
# 2           13 Going on 30  2004           13%20Going%20on%2030
# 3               15 Minutes  2001                   15%20Minutes
# 4                25th Hour  2002                    25th%20Hour
#
#            Image File Name                         Agency Credit  \
# 0  batteriesnotincluded_pf                 Courtesy of Photofest
# 1            12AngryMen_pf                 Courtesy of Photofest
# 2           13Goingon30_ec  Courtesy of Everett Collection, Inc.
# 3                      NaN                                   NaN
# 4             25thHour1_pf                 Courtesy of Photofest
#
#   Artist Credit Director/Filmmaker Name         Director/Filmmaker IMDB Link  \
# 0   Directed by         Matthew Robbins      http://imdb.com/name/nm0730422/
# ...

# %%
df['ratings'] = 0

# %%
df
# Out:
#                         Film  Year                URL Encoded name  \
# 0    *batteries not included  1987   %2Abatteries%20not%20included
# 1               12 Angry Men  1957                12%20Angry%20Men
# 2             13 Going on 30  2004            13%20Going%20on%2030
# 3                 15 Minutes  2001                    15%20Minutes
# 4                  25th Hour  2002                     25th%20Hour
# ..                       ...   ...                             ...
# 228             Working Girl  1988                  Working%20Girl
# 229     You're a Big Boy Now  1966  You%27re%20a%20Big%20Boy%20Now
# 230     You're a Big Boy Now  1966  You%27re%20a%20Big%20Boy%20Now
# 231          You've Got Mail  1998           You%27ve%20Got%20Mail
# 232          You've Got Mail  1998           You%27ve%20Got%20Mail
#
#              Image File Name                         Agency Credit  \
# 0    batteriesnotincluded_pf                 Courtesy of Photofest
# ...

# %%
import requests
import json
import configparser
from pprint import pprint

# %%
url = "http://www.omdbapi.com/?t="
api_key = "&apikey=" + api_key1

# %%
df['Film'][0]
# Out:
# '*batteries not included'

# %%
movie = df['Film'][4]
print(movie)
# Out:
# 25th Hour

# %%
response = requests.get(f"http://www.omdbapi.com/?apikey=72bc447a&t={movie}")

# %%
# Converting the response to JSON, and printing the result.
data = response.json()
pprint(data)
# Out:
# {'Actors': 'Edward Norton, Philip Seymour Hoffman, Barry Pepper, Rosario '
#            'Dawson',
#  'Awards': 'Nominated for 1 Golden Globe. Another 4 wins & 16 nominations.',
#  'BoxOffice': '$13,084,595',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Spike Lee',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '68',
#  'Plot': 'Cornered by the DEA, convicted New York drug dealer Montgomery '
#          'Brogan reevaluates his life in the 24 remaining hours before facing '
#          'a seven-year jail term.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNmE0YjdlYTktMTU4Ni00Mjk2LWI3NWMtM2RjNmFiOTk4YjYxL2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SX300.jpg',
#  'Production': '40 Acres &amp; A Mule Filmworks, Gamut Films, Industry '
#                'Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '78%'},
# ...

# %%
data['Awards']
# Out:
# 'Nominated for 3 Oscars. Another 17 wins & 10 nominations.'

# %%
df = 0.0

# %%
data['imdbRating']
# Out:
# '7.6'

# %%
next(df.iterrows())
# Out:
# (0,
#  Film                                                 *batteries not included
#  Year                                                                    1987
#  URL Encoded name                               %2Abatteries%20not%20included
#  Image File Name                                      batteriesnotincluded_pf
#  Agency Credit                                          Courtesy of Photofest
#  Artist Credit                                                    Directed by
#  Director/Filmmaker Name                                      Matthew Robbins
#  Director/Filmmaker IMDB Link                 http://imdb.com/name/nm0730422/
#  Location Display Text                E. 5th St.<br>East Village<br>Manhattan
#  LATITUDE                                                             40.7224
#  LONGITUDE                                                           -73.9787
#  Borough                                                            Manhattan
# ...

# %%
from time import sleep

# %%
import numpy as np

# %%
df['test'] = np.nan

# %%
del df['test']

# %%
df['Awards'] = np.nan
df['Box Office'] = np.nan
df['Director'] = np.nan
df['Genre'] = np.nan
df['Language'] = np.nan
df['Plot'] = np.nan
df['Poster'] = np.nan
df['Rated'] = np.nan
df['Runtime'] = np.nan
df['imdbID'] = np.nan
df['imdbVotes'] = np.nan

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# {'Actors': 'Edward Norton, Philip Seymour Hoffman, Barry Pepper, Rosario '
#            'Dawson',
#  'Awards': 'Nominated for 1 Golden Globe. Another 4 wins & 16 nominations.',
#  'BoxOffice': '$13,084,595',
#  'Country': 'USA',
#  'DVD': 'N/A',
#  'Director': 'Spike Lee',
#  'Genre': 'Drama',
#  'Language': 'English',
#  'Metascore': '68',
#  'Plot': 'Cornered by the DEA, convicted New York drug dealer Montgomery '
#          'Brogan reevaluates his life in the 24 remaining hours before facing '
#          'a seven-year jail term.',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BNmE0YjdlYTktMTU4Ni00Mjk2LWI3NWMtM2RjNmFiOTk4YjYxL2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SX300.jpg',
#  'Production': '40 Acres &amp; A Mule Filmworks, Gamut Films, Industry '
#                'Entertainment',
#  'Rated': 'R',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.6/10'},
#              {'Source': 'Rotten Tomatoes', 'Value': '78%'},
#              {'Source': 'Metacritic', 'Value': '68/100'}],
#  'Released': '10 Jan 2003',
#  'Response': 'True',
#  'Runtime': '135 min',
#  'Title': '25th Hour',
#  'Type': 'movie',
#  'Website': 'N/A',
#  'Writer': 'David Benioff (novel), David Benioff (screenplay)',
#  'Year': '2002',
#  'imdbID': 'tt0307901',
#  'imdbRating': '7.6',
#  'imdbVotes': '169,256'}

# %%
df['Awards'] = np.nan
df['Box Office'] = np.nan
df['Director'] = np.nan
df['Genre'] = np.nan
df['Plot'] = np.nan
df['Poster'] = np.nan
df['Rated'] = np.nan
df['Runtime'] = np.nan
df['imdbID'] = np.nan
df['imdbVotes'] = np.nan

print(data['Awards'])
print(data['BoxOffice'])
print(data['Director'])
print(data['Genre'])
print(data['Plot'])
print(data['Poster'])
print(data['Rated'])
print(data['Runtime'])
print(data['imdbID'])
print(data['imdbVotes'])
# Out:
# Nominated for 3 Oscars. Another 17 wins & 10 nominations.
# N/A
# Sidney Lumet
# Crime, Drama
# A jury holdout attempts to prevent a miscarriage of justice by forcing his colleagues to reconsider the evidence.
# https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SX300.jpg
# Approved
# 96 min
# tt0050083
# 682,907

# %%
df = df.copy()

# %%
df.head(1)
# Out:
#                       Film  Year               URL Encoded name  \
# 0  *batteries not included  1987  %2Abatteries%20not%20included
#
#            Image File Name          Agency Credit Artist Credit  \
# 0  batteriesnotincluded_pf  Courtesy of Photofest   Directed by
#
#   Director/Filmmaker Name     Director/Filmmaker IMDB Link  \
# 0         Matthew Robbins  http://imdb.com/name/nm0730422/
#
#                      Location Display Text   LATITUDE  LONGITUDE    Borough  \
# 0  E. 5th St.<br>East Village<br>Manhattan  40.722445 -73.978651  Manhattan
#
#    Neighborhood Scene Type Media                         IMDB LINK  \
# 0  East Village        NaN  Film  http://imdb.com/title/tt0092494/
#
#   Client or book location indicator Notes Book Image Book Page Display?  \
# 0                               NaN   NaN          Y       190      NaN
#
#   IMAGE OF LOCATION  ratings  Awards  Box Office  Director  Genre  Language  \
# ...

# %%
# add a timeout here:
# df['Awards'] = np.nan
# df['Box Office'] = np.nan
# df['Director'] = np.nan
# df['Genre'] = np.nan
# df['Language'] = np.nan
# df['Plot'] = np.nan
# df['Poster'] = np.nan
# df['Rated'] = np.nan
# df['Runtime'] = np.nan
# df['Year'] = np.nan
# df['imdbID'] = np.nan
# df['imdbVotes'] = np.nan

# print(data['Awards'])
# print(data['BoxOffice'])
# print(data['Director'])
# print(data['Genre'])
# print(data['Language'])
# print(data['Plot'])
# print(data['Poster'])
# print(data['Rated'])
# print(data['Runtime'])
# print(data['imdbId'])
# print(data['ImdbVotes'])

for index, row in df.iterrows():
    try:
        movie = df['Film'][index]
        response = requests.get(f"http://www.omdbapi.com/?apikey=72bc447a&t={movie}")
        data = response.json()
        try: 
            df['Box Office'][index] = data['BoxOffice']
        except: 
            print(f"none Box Office {index}")
        try: 
            df['Director'][index] = data['Director']
        except: 
            print(f"none Director {index}")
        try:
            df['Genre'][index] = data["Genre"]
        except:
            print(f"none Genre {index}")
        try:
            df['Plot'][index] = data["Plot"]
        except:
            print(f"none Plot {index}")
        try:
            df['Rated'][index] = data['Rated']
        except:
            print(f"none Rated {index}")
        try:
            df['Ratings'][index] = data['Ratings']
        except:
            print(f"none Runtime {index}")
        try:
            df['imdbID'][index] = data['imdbID']
        except: 
            print(f"none imdbId {index}")
        try:
            df['imdbVotes'][index] = data['imdbVotes']
        except:
            print(f"none imdbVotes {index}")
#         df['ratings'][index] = data['Ratings'][0]['Value']
      
# print(foo)
    except:
        print('nope')
    sleep(0.5)
# Out:
# <ipython-input-30-bb1a88b9607a>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Awards'][index] = data['Awards']
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# <ipython-input-30-bb1a88b9607a>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Box Office'][index] = data['BoxOffice']
# ...

# %%
df.iloc[115]
# Out:
# Film                                                              My Dinner with Andre
# Year                                                                              1991
# URL Encoded name                                          My%20Dinner%20with%20Andr%E9
# Image File Name                                                   MyDinnerWithAndre_pf
# Agency Credit                                                    Courtesy of Photofest
# Artist Credit                                                              Directed by
# Director/Filmmaker Name                                                    Louis Malle
# Director/Filmmaker IMDB Link                           http://imdb.com/name/nm0001501/
# Location Display Text                                                          Subway
# LATITUDE                                                                       40.7186
# LONGITUDE                                                                     -73.9884
# ...

# %%
df['Film'][222] = 'When Harry Met Sally'
# Out:
# <ipython-input-39-3a82fc810af5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Film'][222] = 'When Harry Met Sally'

# %%
df['Fil']

# %%
        movie = df['Film'][50]
print(movie)
# Out:
# Downtown 81

# %%
        movie = df['Film'][115]
        response = requests.get(f"http://www.omdbapi.com/?apikey=72bc447a&t={movie}")
        data = response.json()
        try: 
            df['Awards'][115] = data['Awards']
        except: 
            print(f"none Awards{115}")
        try: 
            df['Box Office'][115] = data['BoxOffice']
        except: 
            print(f"none Box Office {115}")
        try: 
            df['Director'][115] = data['Director']
        except: 
            print(f"none Director {115}")
        try:
            df['Genre'][115] = data["Genre"]
        except:
            print(f"none Genre {115}")
        try:
            df['Plot'][115] = data["Plot"]
        except:
            print(f"none Plot {115}")
        try: 
            df['Poster'][115] = data['Poster']
        except:
            print(f"none Poster {115}")
        try:
            df['Rated'][115] = data['Rated']
        except:
            print(f"none Rated {115}")
        try:
            df['Runtime'][115] = data['Runtime']
        except:
            print(f"none Runtime {115}")
        try:
            df['imdbID'][115] = data['imdbID']
        except: 
            print(f"none imdbId {115}")
        try:
            df['imdbVotes'][115] = data['imdbVotes']
        except:
            print(f"none imdbVotes {115}")
# Out:
# <ipython-input-42-64582ab1b71a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Awards'][115] = data['Awards']
# <ipython-input-42-64582ab1b71a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Box Office'][115] = data['BoxOffice']
# <ipython-input-42-64582ab1b71a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Director'][115] = data['Director']
# ...

# %%
df.iloc[222]
# Out:
# Film                                                              When Harry Met Sally
# Year                                                                               NaN
# URL Encoded name                                         When%20Harry%20Met%20Sally%85
# Image File Name                                                  WhenHarryMetSally9_pf
# Agency Credit                                     Courtesy of Everett Collection, Inc.
# Artist Credit                                                              Directed by
# Director/Filmmaker Name                                                     Rob Reiner
# Director/Filmmaker IMDB Link                       http://www.imdb.com/name/nm0001661/
# Location Display Text                   Katz's Deli<br>205 E. Houston St.<br>Manhattan
# LATITUDE                                                                       40.7223
# LONGITUDE                                                                     -73.9874
# ...

# %%
df.iloc[115,0] = "My Dinner With Andre"

# %%
df.iloc[115,0]
# Out:
# 'My Dinner With Andre'

# %%
df.iloc[222, 0]
# Out:
# 'When Harry Met SallyÉ'

# %%
df.iloc[222, 0] = 'When Harry Met Sally'

# %%
df.iloc[115,]
# Out:
# Film                                             My Dinner with Andr
# Year                                                              NaN
# URL Encoded name                         My%20Dinner%20with%20Andr%E9
# Image File Name                                  MyDinnerWithAndre_pf
# Agency Credit                                   Courtesy of Photofest
# Artist Credit                                             Directed by
# Director/Filmmaker Name                                   Louis Malle
# Director/Filmmaker IMDB Link          http://imdb.com/name/nm0001501/
# Location Display Text                                         Subway
# LATITUDE                                                      40.7186
# LONGITUDE                                                    -73.9884
# Borough                                                     Manhattan
# Neighborhood                                          Lower East Side
# ...

# %%
len(df['ratings'][0])
# Out:
# 3

# %%
df['ratings'].tolist()
# Out:
# ['6.7',
#  '9.0',
#  '6.2',
#  '6.1',
#  '7.6',
#  '7.6',
#  '6.5',
#  '7.4',
#  '6.0',
#  '7.7',
#  '6.6',
#  '7.6',
#  '7.1',
#  '8.0',
#  '8.0',
#  '8.0',
#  '8.0',
#  '8.0',
#  '5.7',
#  '7.7',
#  '7.0',
#  '7.0',
#  '6.9',
#  '6.1',
#  '7.3',
#  '6.7',
#  '7.6',
#  '7.6',
#  '7.6',
#  '7.4',
#  '6.8',
#  '6.7',
#  '7.2',
#  '5.2',
#  '6.9',
#  '6.5',
#  '6.5',
#  '6.6',
#  '5.7',
#  '7.0',
#  '6.9',
#  '6.5',
#  '6.5',
#  '6.4',
#  '6.3',
#  '6.0',
#  '6.0',
#  '7.6',
#  '8.0',
#  '8.0',
#  0,
#  0,
#  '8.3/10',
#  '6.6/10',
#  '6.6/10',
#  '7.7/10',
#  '7.3/10',
#  '6.7/10',
#  '7.8/10',
#  '7.8/10',
#  '6.5/10',
#  '6.5/10',
#  '6.5/10',
#  '6.5/10',
#  '6.5/10',
#  '6.5/10',
#  '6.5/10',
#  '6.5/10',
#  '6.4/10',
#  '8.7/10',
#  '6.2/10',
#  '5.7/10',
#  '7.6/10',
#  '7.9/10',
#  '7.9/10',
#  '7.9/10',
#  '6.9/10',
#  '6.6/10',
#  '5.8/10',
#  '6.9/10',
#  '6.6/10',
#  '7.6/10',
#  '6.4/10',
#  '6.9/10',
#  '5.7/10',
#  '6.6/10',
#  '6.6/10',
#  '7.1/10',
#  '6.6/10',
# ...

# %%
df
# Out:
#                         Film  Year                URL Encoded name  \
# 0    *batteries not included  1987   %2Abatteries%20not%20included
# 1               12 Angry Men  1957                12%20Angry%20Men
# 2             13 Going on 30  2004            13%20Going%20on%2030
# 3                 15 Minutes  2001                    15%20Minutes
# 4                  25th Hour  2002                     25th%20Hour
# ..                       ...   ...                             ...
# 228             Working Girl  1988                  Working%20Girl
# 229     You're a Big Boy Now  1966  You%27re%20a%20Big%20Boy%20Now
# 230     You're a Big Boy Now  1966  You%27re%20a%20Big%20Boy%20Now
# 231          You've Got Mail  1998           You%27ve%20Got%20Mail
# 232          You've Got Mail  1998           You%27ve%20Got%20Mail
#
#              Image File Name                         Agency Credit  \
# 0    batteriesnotincluded_pf                 Courtesy of Photofest
# ...

# %%
df['ratings'] = df['ratings'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231 entries, 0 to 230
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Film                               231 non-null    object
#  1   Year                               231 non-null    object
#  2   URL Encoded name                   231 non-null    object
#  3   Image File Name                    180 non-null    object
#  4   Agency Credit                      181 non-null    object
#  5   Artist Credit                      231 non-null    object
#  6   Director/Filmmaker Name            231 non-null    object
#  7   Director/Filmmaker IMDB Link       231 non-null    object
#  8   Location Display Text              231 non-null    object
#  9   LATITUDE                           231 non-null    float64
#  10  LONGITUDE                          231 non-null    float64
# ...

# %%
for index, row in df.iterrows():
    try:
        if len(df['ratings'][index]) > 3:
            df['ratings'][index] = df['ratings'][index][:-3]
    except:
        print('nope')
# Out:
# nope
# nope
# nope
# nope
# nope
# nope
# <ipython-input-76-931a784ac15a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ratings'][index] = df['ratings'][index][:-3]

# %%
df['ratings'].tolist()
# Out:
# [6.7,
#  9.0,
#  6.2,
#  6.1,
#  7.6,
#  7.6,
#  6.5,
#  7.4,
#  6.0,
#  7.7,
#  6.6,
#  7.6,
#  7.1,
#  8.0,
#  8.0,
#  8.0,
#  8.0,
#  8.0,
#  5.7,
#  7.7,
#  7.0,
#  7.0,
#  6.9,
#  6.1,
#  7.3,
#  6.7,
#  7.6,
#  7.6,
#  7.6,
#  7.4,
#  6.8,
#  6.7,
#  7.2,
#  5.2,
#  6.9,
#  6.5,
#  6.5,
#  6.6,
#  5.7,
#  7.0,
#  6.9,
#  6.5,
#  6.5,
#  6.4,
#  6.3,
#  6.0,
#  6.0,
#  7.6,
#  8.0,
#  8.0,
#  0.0,
#  0.0,
#  8.3,
#  6.6,
#  6.6,
#  7.7,
#  7.3,
#  6.7,
#  7.8,
#  7.8,
#  6.5,
#  6.5,
#  6.5,
#  6.5,
#  6.5,
#  6.5,
#  6.5,
#  6.5,
#  6.4,
#  8.7,
#  6.2,
#  5.7,
#  7.6,
#  7.9,
#  7.9,
#  7.9,
#  6.9,
#  6.6,
#  5.8,
#  6.9,
#  6.6,
#  7.6,
#  6.4,
#  6.9,
#  5.7,
#  6.6,
#  6.6,
#  7.1,
#  6.6,
#  7.2,
#  6.4,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.1,
#  7.8,
#  7.4,
#  7.5,
#  7.5,
#  6.0,
#  7.3,
#  7.7,
#  7.0,
#  7.9,
#  7.7,
#  6.9,
#  7.2,
#  7.3,
#  7.3,
#  7.3,
#  7.3,
#  7.8,
#  7.8,
#  7.4,
#  6.6,
#  0.0,
#  6.7,
#  6.9,
#  6.4,
#  7.0,
#  7.0,
#  8.3,
#  7.4,
#  8.1,
# ...

# %%
df.loc[df["ratings"] == 0.0, :]
# Out:
#                                    Film    Year  \
# 50    Downtown 81 / New York Beat Movie    1981
# 116                My Dinner with Andr    1991
# 186  The Late Show with David Letterman  1993-?
#
#                                     URL Encoded name       Image File Name  \
# 50   Downtown%2081%20%2F%20New%20York%20Beat%20Movie       Downtown81_2_pf
# 116                     My%20Dinner%20with%20Andr%E9  MyDinnerWithAndre_pf
# 186     The%20Late%20Show%20with%20David%20Letterman                   NaN
#
#              Agency Credit Artist Credit            Director/Filmmaker Name  \
# 50   Courtesy of Photofest   Directed by                      Edo Bertoglio
# 116  Courtesy of Photofest   Directed by                        Louis Malle
# 186                    NaN   Directed by  Jerry Foley,Randi Grossack,(more)
#
#                           Director/Filmmaker IMDB Link  \
# 50                     http://imdb.com/name/nm0078166/
# ...

# %%
df['ratings'][50]
# Out:
# 0.0

# %%
df
# Out:
#                         Film  Year                URL Encoded name  \
# 0    *batteries not included  1987   %2Abatteries%20not%20included
# 1               12 Angry Men  1957                12%20Angry%20Men
# 2             13 Going on 30  2004            13%20Going%20on%2030
# 3                 15 Minutes  2001                    15%20Minutes
# 4                  25th Hour  2002                     25th%20Hour
# ..                       ...   ...                             ...
# 228             Working Girl  1988                  Working%20Girl
# 229     You're a Big Boy Now  1966  You%27re%20a%20Big%20Boy%20Now
# 230     You're a Big Boy Now  1966  You%27re%20a%20Big%20Boy%20Now
# 231          You've Got Mail  1998           You%27ve%20Got%20Mail
# 232          You've Got Mail  1998           You%27ve%20Got%20Mail
#
#              Image File Name                         Agency Credit  \
# 0    batteriesnotincluded_pf                 Courtesy of Photofest
# ...

# %%
df.describe()
# Out:
#          LATITUDE   LONGITUDE     ratings  Language
# count  231.000000  231.000000  231.000000     231.0
# mean    40.739816  -73.979165    6.917316       0.0
# std      0.052986    0.028234    1.117121       0.0
# min     40.572232  -74.072721    0.000000       0.0
# 25%     40.713576  -73.996401    6.500000       0.0
# 50%     40.752589  -73.982100    7.000000       0.0
# 75%     40.772323  -73.970655    7.600000       0.0
# max     40.859460  -73.841257    9.200000       0.0

# %%
file = 'nyc_movies_with_all_info.csv'
df3 = pd.read_csv(file, encoding='UTF-8')

# %%
pwd
# Out:
# '/Users/stanleytan/Desktop/bootcampspot/4-Project/2nd_project/second_step/movies'

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212 entries, 0 to 230
# Data columns (total 33 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Film                               212 non-null    object
#  1   Year                               212 non-null    float64
#  2   URL Encoded name                   212 non-null    object
#  3   Image File Name                    212 non-null    object
#  4   Agency Credit                      212 non-null    object
#  5   Artist Credit                      212 non-null    object
#  6   Director/Filmmaker Name            212 non-null    object
#  7   Director/Filmmaker IMDB Link       212 non-null    object
#  8   Location Display Text              212 non-null    object
#  9   LATITUDE                           212 non-null    float64
#  10  LONGITUDE                          212 non-null    float64
# ...

# %%
df = df.fillna(0)

# %%
df3['ratings'] = df3['ratings'].astype('int64')
# df.Weight = df.Weight.astype('int64')

# %%
newdf = out.loc[out['rating'] >= 4.5, :]

# %%
df = df.loc[df['ratings'] >= 6, :]

# %%
df.describe()
# Out:
#          LATITUDE   LONGITUDE     ratings  Language
# count  212.000000  212.000000  212.000000     212.0
# mean    40.739909  -73.979240    7.128302       0.0
# std      0.052709    0.028290    0.657044       0.0
# min     40.572232  -74.072721    6.000000       0.0
# 25%     40.714679  -73.995158    6.600000       0.0
# 50%     40.752784  -73.981918    7.100000       0.0
# 75%     40.772313  -73.970931    7.600000       0.0
# max     40.859460  -73.841257    9.200000       0.0

# %%
df = df.drop(51)

# %%
df.to_csv('nyc_movies_for_geojson.csv', index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Film                               233 non-null    object
#  1   Year                               233 non-null    object
#  2   URL Encoded name                   233 non-null    object
#  3   Image File Name                    182 non-null    object
#  4   Agency Credit                      183 non-null    object
#  5   Artist Credit                      233 non-null    object
#  6   Director/Filmmaker Name            233 non-null    object
#  7   Director/Filmmaker IMDB Link       233 non-null    object
#  8   Location Display Text              233 non-null    object
#  9   LATITUDE                           233 non-null    float64
#  10  LONGITUDE                          233 non-null    float64
# ...

# %%
foo = df['ratings'][0]

# %%
type(foo)
# Out:
# str

# %%
len(foo)
# Out:
# 6

# %%
if len(foo) > 1:
    foo = foo[:-3]
print(foo)
# Out:
# 6.7

# %%
# Out:
# True

# %%
foo = foo[:-3]
print(foo)
# Out:
# he
